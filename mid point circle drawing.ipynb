# %%
import matplotlib.pyplot as plt

# %%
def draw_circle_midpoint(xc, yc, radius):
    x = 0
    y = radius
    p = 1 - radius

    # Store all points to plot
    x_points = []
    y_points = []

    def plot_circle_points(xc, yc, x, y):
        points = [
            (xc + x, yc + y),
            (xc - x, yc + y),
            (xc + x, yc - y),
            (xc - x, yc - y),
            (xc + y, yc + x),
            (xc - y, yc + x),
            (xc + y, yc - x),
            (xc - y, yc - x),
        ]
        for px, py in points:
            x_points.append(px)
            y_points.append(py)

    plot_circle_points(xc, yc, x, y)

    while x < y:
        x += 1
        if p < 0:
            p += 2 * x + 1
        else:
            y -= 1
            p += 2 * (x - y) + 1
        plot_circle_points(xc, yc, x, y)
    # Plot using matplotlib
    plt.figure(figsize=(6, 6))
    plt.scatter(x_points, y_points, color="blue", s=10)
    plt.axhline(0, color='gray')  # X-axis
    plt.axvline(0, color='gray')  # Y-axis
    plt.title("Midpoint Circle Drawing Algorithm")
    plt.gca().set_aspect('equal', adjustable='box')
    plt.grid(True)
    plt.show()

# %%
# Get user input
center_x = int(input("Enter center x: "))
center_y = int(input("Enter center y: "))
radius = int(input("Enter radius: "))

# %%
print('Input')
print('Enter center x:', center_x)
print('Enter center y:', center_y)
print('Enter radius:', radius)
# Out:
# Input
# Enter center x: 5
# Enter center y: 5
# Enter radius: 80

# %%
draw_circle_midpoint(center_x, center_y, radius)
